# %% [markdown]
# ### Import packages and dataset

# %%
import pandas as pd
import numpy as np
import json
import ast

df = pd.read_csv('LOL/LeagueofLegends.csv')

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7620 entries, 0 to 7619
# Data columns (total 57 columns):
# League              7620 non-null object
# Year                7620 non-null int64
# Season              7620 non-null object
# Type                7620 non-null object
# blueTeamTag         7582 non-null object
# bResult             7620 non-null int64
# rResult             7620 non-null int64
# redTeamTag          7583 non-null object
# gamelength          7620 non-null int64
# golddiff            7620 non-null object
# goldblue            7620 non-null object
# bKills              7620 non-null object
# bTowers             7620 non-null object
# bInhibs             7620 non-null object
# bDragons            7620 non-null object
# bBarons             7620 non-null object
# bHeralds            7620 non-null object
# goldred             7620 non-null object
# rKills              7620 non-null object
# rTowers             7620 non-null object
# rInhibs             7620 non-null object
# rDragons            7620 non-null object
# rBarons             7620 non-null object
# rHeralds            7620 non-null object
# blueTop             7583 non-null object
# blueTopChamp        7620 non-null object
# goldblueTop         7620 non-null object
# blueJungle          7592 non-null object
# blueJungleChamp     7620 non-null object
# goldblueJungle      7620 non-null object
# blueMiddle          7583 non-null object
# blueMiddleChamp     7620 non-null object
# goldblueMiddle      7620 non-null object
# blueADC             7583 non-null object
# blueADCChamp        7620 non-null object
# goldblueADC         7620 non-null object
# blueSupport         7583 non-null object
# blueSupportChamp    7620 non-null object
# goldblueSupport     7620 non-null object
# blueBans            7620 non-null object
# redTop              7583 non-null object
# redTopChamp         7620 non-null object
# goldredTop          7620 non-null object
# redJungle           7596 non-null object
# redJungleChamp      7620 non-null object
# goldredJungle       7620 non-null object
# redMiddle           7583 non-null object
# redMiddleChamp      7620 non-null object
# goldredMiddle       7620 non-null object
# redADC              7583 non-null object
# redADCChamp         7620 non-null object
# goldredADC          7620 non-null object
# redSupport          7583 non-null object
# redSupportChamp     7620 non-null object
# goldredSupport      7620 non-null object
# redBans             7620 non-null object
# Address             7620 non-null object
# dtypes: int64(4), object(53)
# memory usage: 3.3+ MB
# None

# %% [markdown]
# ### Explore sample row

# %%
for cols in df.columns:
    print('\nDatapoint #10 in {}: \n==>\t{}'.format(cols, df[cols][10]))
# Out:
# Datapoint #10 in League:
# ==>	NALCS
#
# Datapoint #10 in Year:
# ==>	2015
#
# Datapoint #10 in Season:
# ==>	Spring
#
# Datapoint #10 in Type:
# ==>	Season
#
# Datapoint #10 in blueTeamTag:
# ==>	GV
#
# Datapoint #10 in bResult:
# ==>	1
#
# Datapoint #10 in rResult:
# ==>	0
#
# Datapoint #10 in redTeamTag:
# ==>	DIG
#
# Datapoint #10 in gamelength:
# ==>	52
#
# Datapoint #10 in golddiff:
# ==>	[0, -10, -15, -274, -154, -49, 134, 122, 391, 423, 534, 462, 611, 704, 1383, 989, 1711, 2633, 2806, 2978, 3074, 4779, 4782, 4901, 4710, 5156, 4819, 4936, 6265, 6198, 6537, 6664, 6800, 6810, 6492, 6755, 7299, 7451, 7574, 7368, 7063, 7176, 7524, 7707, 7880, 7067, 6844, 6963, 8097, 9963, 10528, 12212]
#
# Datapoint #10 in goldblue:
# ==>	[2415, 2415, 2716, 3843, 5190, 6687, 8109, 9421, 10854, 12389, 13931, 15242, 16590, 18201, 19936, 21125, 23381, 25536, 27097, 28535, 29669, 32282, 33522, 35206, 36835, 38388, 39422, 40741, 43478, 44944, 46608, 47794, 49448, 50513, 51790, 53010, 54998, 56562, 57763, 58917, 59861, 61993, 63552, 64987, 66202, 67088, 68433, 69572, 71756, 74979, 76820, 79673]
#
# Datapoint #10 in bKills:
# ==>	[[20.55, 'DIG Crumbzz', 'GV Keane', ['GV Hauntzer', 'GV Bunny FuFuu'], 8962, 9139], [22.446, 'DIG Crumbzz', 'GV Cop', ['GV Saintvicious', 'GV Keane'], 6944, 7829], [48.511, 'DIG Crumbzz', 'GV Cop', ['GV Saintvicious', 'GV Keane', 'GV Bunny FuFuu'], 8582, 11476], [50.872, 'DIG Shiphtur', 'GV Cop', ['GV Hauntzer', 'GV Saintvicious', 'GV Bunny FuFuu'], 13884, 11558], [51.36, 'DIG CoreJJ', 'GV Cop', ['GV Hauntzer', 'GV Keane', 'GV Bunny FuFuu'], 11293, 11754]]
#
# Datapoint #10 in bTowers:
# ==>	[[15.531, 'TOP_LANE', 'OUTER_TURRET'], [50.663, 'BOT_LANE', 'BASE_TURRET'], [35.094, 'TOP_LANE', 'INNER_TURRET'], [27.009, 'BOT_LANE', 'INNER_TURRET'], [16.449, 'BOT_LANE', 'OUTER_TURRET'], [40.927, 'MID_LANE', 'BASE_TURRET'], [20.787, 'MID_LANE', 'OUTER_TURRET'], [27.17, 'MID_LANE', 'INNER_TURRET'], [51.235, 'MID_LANE', 'NEXUS_TURRET'], [51.318, 'MID_LANE', 'NEXUS_TURRET'], [49.324, 'TOP_LANE', 'BASE_TURRET']]
#
# Datapoint #10 in bInhibs:
# ==>	[[46.475, 'MID_LANE'], [49.471, 'TOP_LANE'], [50.932, 'BOT_LANE']]
#
# Datapoint #10 in bDragons:
# ==>	[[39.705, None], [45.892, None], [20.104, None], [26.262, None], [32.978, None]]
#
# Datapoint #10 in bBarons:
# ==>	[[48.915]]
#
# Datapoint #10 in bHeralds:
# ==>	[]
#
# Datapoint #10 in goldred:
# ==>	[2415, 2425, 2731, 4117, 5344, 6736, 7975, 9299, 10463, 11966, 13397, 14780, 15979, 17497, 18553, 20136, 21670, 22903, 24291, 25557, 26595, 27503, 28740, 30305, 32125, 33232, 34603, 35805, 37213, 38746, 40071, 41130, 42648, 43703, 45298, 46255, 47699, 49111, 50189, 51549, 52798, 54817, 56028, 57280, 58322, 60021, 61589, 62609, 63659, 65016, 66292, 67461]
#
# Datapoint #10 in rKills:
# ==>	[[22.492, 'GV Keane', 'DIG Shiphtur', ['DIG Gamsu', 'DIG Crumbzz', 'DIG CoreJJ'], 6623, 9186], [28.88, 'GV Bunny FuFuu', 'DIG CoreJJ', ['DIG Gamsu', 'DIG Shiphtur'], 5520, 5952], [38.318, 'GV Bunny FuFuu', 'DIG Shiphtur', ['DIG Crumbzz'], 3032, 8094], [51.339, 'GV Keane', 'DIG CoreJJ', ['DIG Gamsu', 'DIG Crumbzz', 'DIG KiWiKiD'], 11710, 12560]]
#
# Datapoint #10 in rTowers:
# ==>	[[29.936, 'BOT_LANE', 'FOUNTAIN_TURRET'], [23.079, 'MID_LANE', 'OUTER_TURRET'], [24.497, 'BOT_LANE', 'FOUNTAIN_TURRET'], [40.492, 'TOP_LANE', 'OUTER_TURRET'], [35.638, 'BOT_LANE', 'FOUNTAIN_TURRET'], [45.914, 'BOT_LANE', 'FOUNTAIN_TURRET'], [41.439, 'BOT_LANE', 'FOUNTAIN_TURRET']]
#
# Datapoint #10 in rInhibs:
# ==>	[]
#
# Datapoint #10 in rDragons:
# ==>	[[13.393, None]]
#
# Datapoint #10 in rBarons:
# ==>	[]
#
# Datapoint #10 in rHeralds:
# ==>	[]
#
# Datapoint #10 in blueTop:
# ==>	Hauntzer
#
# Datapoint #10 in blueTopChamp:
# ==>	Gnar
#
# Datapoint #10 in goldblueTop:
# ==>	[475, 475, 533, 792, 1121, 1469, 1751, 2122, 2433, 2746, 3090, 3321, 3716, 4077, 4462, 4789, 5436, 5937, 6411, 6722, 7016, 7438, 7619, 7902, 8498, 8676, 8826, 9013, 9604, 9911, 10392, 10695, 11074, 11244, 11515, 11740, 12086, 12580, 12854, 12966, 13088, 13527, 13730, 13942, 14217, 14331, 14587, 14701, 15387, 16096, 16411, 16853]
#
# Datapoint #10 in blueJungle:
# ==>	Saintvicious
#
# Datapoint #10 in blueJungleChamp:
# ==>	JarvanIV
#
# Datapoint #10 in goldblueJungle:
# ==>	[475, 475, 533, 789, 1031, 1440, 1759, 1966, 2228, 2640, 2848, 3063, 3286, 3616, 4157, 4286, 4555, 4954, 5369, 5513, 5729, 6190, 6519, 6965, 7199, 7601, 7821, 8089, 8503, 8923, 9099, 9228, 9535, 9703, 9832, 9945, 10320, 10640, 10784, 10966, 11092, 11527, 11642, 12096, 12322, 12487, 12656, 12770, 13168, 13717, 14118, 14510]
#
# Datapoint #10 in blueMiddle:
# ==>	Keane
#
# Datapoint #10 in blueMiddleChamp:
# ==>	Azir
#
# Datapoint #10 in goldblueMiddle:
# ==>	[475, 475, 533, 777, 1071, 1343, 1605, 1925, 2277, 2610, 3087, 3387, 3693, 4072, 4399, 4688, 5286, 5664, 6003, 6390, 6607, 7394, 7697, 7879, 8225, 8654, 8881, 9245, 9935, 10129, 10441, 10660, 11073, 11495, 11817, 12072, 12470, 12614, 12912, 13240, 13378, 13735, 14190, 14559, 14765, 14970, 15273, 15714, 15870, 16360, 16649, 17169]
#
# Datapoint #10 in blueADC:
# ==>	Cop
#
# Datapoint #10 in blueADCChamp:
# ==>	Corki
#
# Datapoint #10 in goldblueADC:
# ==>	[475, 475, 533, 752, 1081, 1358, 1757, 2019, 2387, 2721, 3076, 3454, 3734, 4117, 4436, 4730, 5205, 5748, 5935, 6322, 6574, 7117, 7398, 7973, 8243, 8623, 8918, 9251, 9825, 10215, 10774, 11100, 11486, 11618, 11969, 12457, 13039, 13510, 13808, 14207, 14629, 15199, 15806, 16068, 16433, 16689, 17095, 17398, 18186, 19134, 19645, 20656]
#
# Datapoint #10 in blueSupport:
# ==>	Bunny FuFuu
#
# Datapoint #10 in blueSupportChamp:
# ==>	Morgana
#
# Datapoint #10 in goldblueSupport:
# ==>	[515, 515, 584, 733, 886, 1077, 1237, 1389, 1529, 1672, 1830, 2017, 2161, 2319, 2482, 2632, 2899, 3233, 3379, 3588, 3743, 4143, 4289, 4487, 4670, 4834, 4976, 5143, 5611, 5766, 5902, 6111, 6280, 6453, 6657, 6796, 7083, 7218, 7405, 7538, 7674, 8005, 8184, 8322, 8465, 8611, 8822, 8989, 9145, 9672, 9997, 10485]
#
# Datapoint #10 in blueBans:
# ==>	['Irelia', 'Annie', 'Sivir']
#
# Datapoint #10 in redTop:
# ==>	Gamsu
#
# Datapoint #10 in redTopChamp:
# ==>	Lulu
#
# Datapoint #10 in goldredTop:
# ==>	[475, 475, 533, 777, 1091, 1393, 1686, 1995, 2270, 2566, 2878, 3236, 3511, 3881, 4115, 4403, 4712, 4947, 5271, 5588, 5782, 5977, 6252, 6471, 6910, 7106, 7502, 7910, 8261, 8514, 8814, 9055, 9328, 9515, 9989, 10209, 10572, 10889, 11033, 11214, 11421, 11780, 11929, 12072, 12262, 12879, 13077, 13221, 13522, 13906, 14123, 14409]
#
# Datapoint #10 in redJungle:
# ==>	Crumbzz
#
# Datapoint #10 in redJungleChamp:
# ==>	LeeSin
#
# Datapoint #10 in goldredJungle:
# ==>	[475, 475, 533, 896, 1092, 1361, 1665, 1859, 2182, 2462, 2813, 3040, 3252, 3564, 3832, 4161, 4452, 4693, 4930, 5059, 5203, 5421, 5667, 5971, 6239, 6399, 6573, 6777, 7003, 7132, 7495, 7668, 7951, 8079, 8484, 8597, 8735, 8894, 9023, 9375, 9490, 9729, 9954, 10097, 10267, 10381, 10560, 10674, 10811, 10925, 11103, 11468]
#
# Datapoint #10 in redMiddle:
# ==>	Shiphtur
#
# Datapoint #10 in redMiddleChamp:
# ==>	Xerath
#
# Datapoint #10 in goldredMiddle:
# ==>	[475, 475, 533, 842, 1126, 1458, 1675, 1948, 2202, 2584, 2829, 3154, 3450, 3774, 4004, 4423, 4784, 5204, 5515, 5778, 6083, 6313, 6490, 7095, 7452, 7747, 8008, 8224, 8666, 9060, 9277, 9513, 10072, 10266, 10680, 10874, 11284, 11747, 12004, 12482, 13066, 13442, 13767, 14109, 14449, 14794, 15420, 15663, 15877, 16141, 16490, 16747]
#
# Datapoint #10 in redADC:
# ==>	CoreJJ
#
# Datapoint #10 in redADCChamp:
# ==>	Ezreal
#
# Datapoint #10 in goldredADC:
# ==>	[475, 475, 533, 842, 1131, 1454, 1736, 2138, 2314, 2710, 3086, 3416, 3679, 4047, 4162, 4505, 4893, 5095, 5470, 5876, 6101, 6216, 6618, 6914, 7360, 7644, 8041, 8268, 8522, 9138, 9361, 9633, 9899, 10306, 10472, 10738, 11069, 11394, 11775, 11982, 12180, 12935, 13301, 13759, 13959, 14438, 14862, 15235, 15491, 15904, 16247, 16383]
#
# Datapoint #10 in redSupport:
# ==>	KiWiKiD
#
# Datapoint #10 in redSupportChamp:
# ==>	Janna
#
# Datapoint #10 in goldredSupport:
# ==>	[515, 525, 599, 760, 904, 1070, 1213, 1359, 1495, 1644, 1791, 1934, 2087, 2231, 2440, 2644, 2829, 2964, 3105, 3256, 3426, 3576, 3713, 3854, 4164, 4336, 4479, 4626, 4761, 4902, 5124, 5261, 5398, 5537, 5673, 5837, 6039, 6187, 6354, 6496, 6641, 6931, 7077, 7243, 7385, 7529, 7670, 7816, 7958, 8140, 8329, 8454]
#
# Datapoint #10 in redBans:
# ==>	['RekSai', 'Lissandra', 'Kassadin']
#
# Datapoint #10 in Address:
# ==>	http://matchhistory.na.leagueoflegends.com/en/#match-details/TRLH1/1001000016?gameHash=e8fbe00273df6ede

# %% [markdown]
# ### Define columns to be modified, and begin transformation based on lambda functions to parse data to list form

# %%
count_cols = ['goldred', 'bKills', 'rKills', 'bTowers', 'rTowers', 'bInhibs', 'rInhibs', 
            'bDragons', 'rDragons', 'bBarons', 'rBarons', 'bHeralds', 'rHeralds']

champ_gold_cols = ['goldblueTop', 'goldblueMiddle', 'goldblueJungle', 'goldblueSupport', 'goldblueADC', 
                    'goldredTop', 'goldredMiddle', 'goldredJungle', 'goldredSupport', 'goldredADC']

# goldred - goldblue

for cols in count_cols:
    if cols in ['goldred', 'goldblue']:
        df[cols] = df.apply(lambda row: json.loads(row[cols]), axis=1)
    else:
        df[cols] = df.apply(lambda row: ast.literal_eval(row[cols]), axis=1)
        df[str(cols+'_pre15')] = df.apply(lambda row: sum([1 if int(i[0]) <= 15 else 0 for i in row[cols]]), axis=1)


for cols in champ_gold_cols:
    df[cols] = df.apply(lambda row: json.loads(row[cols]), axis=1)

players = ['TopgoldDiff', 'MidgoldDiff', 'JunglegoldDiff', 'SupportgoldDiff', 'ADCgoldDiff']
blue_players_gold = ['goldblueTop', 'goldblueMiddle', 'goldblueJungle', 'goldblueSupport', 'goldblueADC']
red_players_gold = ['goldredTop', 'goldredMiddle', 'goldredJungle', 'goldredSupport', 'goldredADC']

for rChampG, bChampG, Champ in zip(red_players_gold, blue_players_gold, players):
    df[Champ] = df.apply(lambda row: np.subtract(row[rChampG], row[bChampG]), axis=1)
    pass

df['golddiff_min15'] = df.apply(lambda row: json.loads(row['golddiff'])[15], axis=1)
df['golddiff_final'] = df.apply(lambda row: json.loads(row['golddiff'])[-1], axis=1)

# %% [markdown]
# ### Explore modified dataset

# %%
for cols in df.columns:
    print('\nDatapoint #10 in {}: \n==>\t{}'.format(cols, df[cols][10]))
# Out:
# Datapoint #10 in League:
# ==>	NALCS
#
# Datapoint #10 in Year:
# ==>	2015
#
# Datapoint #10 in Season:
# ==>	Spring
#
# Datapoint #10 in Type:
# ==>	Season
#
# Datapoint #10 in blueTeamTag:
# ==>	GV
#
# Datapoint #10 in bResult:
# ==>	1
#
# Datapoint #10 in rResult:
# ==>	0
#
# Datapoint #10 in redTeamTag:
# ==>	DIG
#
# Datapoint #10 in gamelength:
# ==>	52
#
# Datapoint #10 in golddiff:
# ==>	[0, -10, -15, -274, -154, -49, 134, 122, 391, 423, 534, 462, 611, 704, 1383, 989, 1711, 2633, 2806, 2978, 3074, 4779, 4782, 4901, 4710, 5156, 4819, 4936, 6265, 6198, 6537, 6664, 6800, 6810, 6492, 6755, 7299, 7451, 7574, 7368, 7063, 7176, 7524, 7707, 7880, 7067, 6844, 6963, 8097, 9963, 10528, 12212]
#
# Datapoint #10 in goldblue:
# ==>	[2415, 2415, 2716, 3843, 5190, 6687, 8109, 9421, 10854, 12389, 13931, 15242, 16590, 18201, 19936, 21125, 23381, 25536, 27097, 28535, 29669, 32282, 33522, 35206, 36835, 38388, 39422, 40741, 43478, 44944, 46608, 47794, 49448, 50513, 51790, 53010, 54998, 56562, 57763, 58917, 59861, 61993, 63552, 64987, 66202, 67088, 68433, 69572, 71756, 74979, 76820, 79673]
#
# Datapoint #10 in bKills:
# ==>	[[20.55, 'DIG Crumbzz', 'GV Keane', ['GV Hauntzer', 'GV Bunny FuFuu'], 8962, 9139], [22.446, 'DIG Crumbzz', 'GV Cop', ['GV Saintvicious', 'GV Keane'], 6944, 7829], [48.511, 'DIG Crumbzz', 'GV Cop', ['GV Saintvicious', 'GV Keane', 'GV Bunny FuFuu'], 8582, 11476], [50.872, 'DIG Shiphtur', 'GV Cop', ['GV Hauntzer', 'GV Saintvicious', 'GV Bunny FuFuu'], 13884, 11558], [51.36, 'DIG CoreJJ', 'GV Cop', ['GV Hauntzer', 'GV Keane', 'GV Bunny FuFuu'], 11293, 11754]]
#
# Datapoint #10 in bTowers:
# ==>	[[15.531, 'TOP_LANE', 'OUTER_TURRET'], [50.663, 'BOT_LANE', 'BASE_TURRET'], [35.094, 'TOP_LANE', 'INNER_TURRET'], [27.009, 'BOT_LANE', 'INNER_TURRET'], [16.449, 'BOT_LANE', 'OUTER_TURRET'], [40.927, 'MID_LANE', 'BASE_TURRET'], [20.787, 'MID_LANE', 'OUTER_TURRET'], [27.17, 'MID_LANE', 'INNER_TURRET'], [51.235, 'MID_LANE', 'NEXUS_TURRET'], [51.318, 'MID_LANE', 'NEXUS_TURRET'], [49.324, 'TOP_LANE', 'BASE_TURRET']]
#
# Datapoint #10 in bInhibs:
# ==>	[[46.475, 'MID_LANE'], [49.471, 'TOP_LANE'], [50.932, 'BOT_LANE']]
#
# Datapoint #10 in bDragons:
# ==>	[[39.705, None], [45.892, None], [20.104, None], [26.262, None], [32.978, None]]
#
# Datapoint #10 in bBarons:
# ==>	[[48.915]]
#
# Datapoint #10 in bHeralds:
# ==>	[]
#
# Datapoint #10 in goldred:
# ==>	[2415, 2425, 2731, 4117, 5344, 6736, 7975, 9299, 10463, 11966, 13397, 14780, 15979, 17497, 18553, 20136, 21670, 22903, 24291, 25557, 26595, 27503, 28740, 30305, 32125, 33232, 34603, 35805, 37213, 38746, 40071, 41130, 42648, 43703, 45298, 46255, 47699, 49111, 50189, 51549, 52798, 54817, 56028, 57280, 58322, 60021, 61589, 62609, 63659, 65016, 66292, 67461]
#
# Datapoint #10 in rKills:
# ==>	[[22.492, 'GV Keane', 'DIG Shiphtur', ['DIG Gamsu', 'DIG Crumbzz', 'DIG CoreJJ'], 6623, 9186], [28.88, 'GV Bunny FuFuu', 'DIG CoreJJ', ['DIG Gamsu', 'DIG Shiphtur'], 5520, 5952], [38.318, 'GV Bunny FuFuu', 'DIG Shiphtur', ['DIG Crumbzz'], 3032, 8094], [51.339, 'GV Keane', 'DIG CoreJJ', ['DIG Gamsu', 'DIG Crumbzz', 'DIG KiWiKiD'], 11710, 12560]]
#
# Datapoint #10 in rTowers:
# ==>	[[29.936, 'BOT_LANE', 'FOUNTAIN_TURRET'], [23.079, 'MID_LANE', 'OUTER_TURRET'], [24.497, 'BOT_LANE', 'FOUNTAIN_TURRET'], [40.492, 'TOP_LANE', 'OUTER_TURRET'], [35.638, 'BOT_LANE', 'FOUNTAIN_TURRET'], [45.914, 'BOT_LANE', 'FOUNTAIN_TURRET'], [41.439, 'BOT_LANE', 'FOUNTAIN_TURRET']]
#
# Datapoint #10 in rInhibs:
# ==>	[]
#
# Datapoint #10 in rDragons:
# ==>	[[13.393, None]]
#
# Datapoint #10 in rBarons:
# ==>	[]
#
# Datapoint #10 in rHeralds:
# ==>	[]
#
# Datapoint #10 in blueTop:
# ==>	Hauntzer
#
# Datapoint #10 in blueTopChamp:
# ==>	Gnar
#
# Datapoint #10 in goldblueTop:
# ==>	[475, 475, 533, 792, 1121, 1469, 1751, 2122, 2433, 2746, 3090, 3321, 3716, 4077, 4462, 4789, 5436, 5937, 6411, 6722, 7016, 7438, 7619, 7902, 8498, 8676, 8826, 9013, 9604, 9911, 10392, 10695, 11074, 11244, 11515, 11740, 12086, 12580, 12854, 12966, 13088, 13527, 13730, 13942, 14217, 14331, 14587, 14701, 15387, 16096, 16411, 16853]
#
# Datapoint #10 in blueJungle:
# ==>	Saintvicious
#
# Datapoint #10 in blueJungleChamp:
# ==>	JarvanIV
#
# Datapoint #10 in goldblueJungle:
# ==>	[475, 475, 533, 789, 1031, 1440, 1759, 1966, 2228, 2640, 2848, 3063, 3286, 3616, 4157, 4286, 4555, 4954, 5369, 5513, 5729, 6190, 6519, 6965, 7199, 7601, 7821, 8089, 8503, 8923, 9099, 9228, 9535, 9703, 9832, 9945, 10320, 10640, 10784, 10966, 11092, 11527, 11642, 12096, 12322, 12487, 12656, 12770, 13168, 13717, 14118, 14510]
#
# Datapoint #10 in blueMiddle:
# ==>	Keane
#
# Datapoint #10 in blueMiddleChamp:
# ==>	Azir
#
# Datapoint #10 in goldblueMiddle:
# ==>	[475, 475, 533, 777, 1071, 1343, 1605, 1925, 2277, 2610, 3087, 3387, 3693, 4072, 4399, 4688, 5286, 5664, 6003, 6390, 6607, 7394, 7697, 7879, 8225, 8654, 8881, 9245, 9935, 10129, 10441, 10660, 11073, 11495, 11817, 12072, 12470, 12614, 12912, 13240, 13378, 13735, 14190, 14559, 14765, 14970, 15273, 15714, 15870, 16360, 16649, 17169]
#
# Datapoint #10 in blueADC:
# ==>	Cop
#
# Datapoint #10 in blueADCChamp:
# ==>	Corki
#
# Datapoint #10 in goldblueADC:
# ==>	[475, 475, 533, 752, 1081, 1358, 1757, 2019, 2387, 2721, 3076, 3454, 3734, 4117, 4436, 4730, 5205, 5748, 5935, 6322, 6574, 7117, 7398, 7973, 8243, 8623, 8918, 9251, 9825, 10215, 10774, 11100, 11486, 11618, 11969, 12457, 13039, 13510, 13808, 14207, 14629, 15199, 15806, 16068, 16433, 16689, 17095, 17398, 18186, 19134, 19645, 20656]
#
# Datapoint #10 in blueSupport:
# ==>	Bunny FuFuu
#
# Datapoint #10 in blueSupportChamp:
# ==>	Morgana
#
# Datapoint #10 in goldblueSupport:
# ==>	[515, 515, 584, 733, 886, 1077, 1237, 1389, 1529, 1672, 1830, 2017, 2161, 2319, 2482, 2632, 2899, 3233, 3379, 3588, 3743, 4143, 4289, 4487, 4670, 4834, 4976, 5143, 5611, 5766, 5902, 6111, 6280, 6453, 6657, 6796, 7083, 7218, 7405, 7538, 7674, 8005, 8184, 8322, 8465, 8611, 8822, 8989, 9145, 9672, 9997, 10485]
#
# Datapoint #10 in blueBans:
# ==>	['Irelia', 'Annie', 'Sivir']
#
# Datapoint #10 in redTop:
# ==>	Gamsu
#
# Datapoint #10 in redTopChamp:
# ==>	Lulu
#
# Datapoint #10 in goldredTop:
# ==>	[475, 475, 533, 777, 1091, 1393, 1686, 1995, 2270, 2566, 2878, 3236, 3511, 3881, 4115, 4403, 4712, 4947, 5271, 5588, 5782, 5977, 6252, 6471, 6910, 7106, 7502, 7910, 8261, 8514, 8814, 9055, 9328, 9515, 9989, 10209, 10572, 10889, 11033, 11214, 11421, 11780, 11929, 12072, 12262, 12879, 13077, 13221, 13522, 13906, 14123, 14409]
#
# Datapoint #10 in redJungle:
# ==>	Crumbzz
#
# Datapoint #10 in redJungleChamp:
# ==>	LeeSin
#
# Datapoint #10 in goldredJungle:
# ==>	[475, 475, 533, 896, 1092, 1361, 1665, 1859, 2182, 2462, 2813, 3040, 3252, 3564, 3832, 4161, 4452, 4693, 4930, 5059, 5203, 5421, 5667, 5971, 6239, 6399, 6573, 6777, 7003, 7132, 7495, 7668, 7951, 8079, 8484, 8597, 8735, 8894, 9023, 9375, 9490, 9729, 9954, 10097, 10267, 10381, 10560, 10674, 10811, 10925, 11103, 11468]
#
# Datapoint #10 in redMiddle:
# ==>	Shiphtur
#
# Datapoint #10 in redMiddleChamp:
# ==>	Xerath
#
# Datapoint #10 in goldredMiddle:
# ==>	[475, 475, 533, 842, 1126, 1458, 1675, 1948, 2202, 2584, 2829, 3154, 3450, 3774, 4004, 4423, 4784, 5204, 5515, 5778, 6083, 6313, 6490, 7095, 7452, 7747, 8008, 8224, 8666, 9060, 9277, 9513, 10072, 10266, 10680, 10874, 11284, 11747, 12004, 12482, 13066, 13442, 13767, 14109, 14449, 14794, 15420, 15663, 15877, 16141, 16490, 16747]
#
# Datapoint #10 in redADC:
# ==>	CoreJJ
#
# Datapoint #10 in redADCChamp:
# ==>	Ezreal
#
# Datapoint #10 in goldredADC:
# ==>	[475, 475, 533, 842, 1131, 1454, 1736, 2138, 2314, 2710, 3086, 3416, 3679, 4047, 4162, 4505, 4893, 5095, 5470, 5876, 6101, 6216, 6618, 6914, 7360, 7644, 8041, 8268, 8522, 9138, 9361, 9633, 9899, 10306, 10472, 10738, 11069, 11394, 11775, 11982, 12180, 12935, 13301, 13759, 13959, 14438, 14862, 15235, 15491, 15904, 16247, 16383]
#
# Datapoint #10 in redSupport:
# ==>	KiWiKiD
#
# Datapoint #10 in redSupportChamp:
# ==>	Janna
#
# Datapoint #10 in goldredSupport:
# ==>	[515, 525, 599, 760, 904, 1070, 1213, 1359, 1495, 1644, 1791, 1934, 2087, 2231, 2440, 2644, 2829, 2964, 3105, 3256, 3426, 3576, 3713, 3854, 4164, 4336, 4479, 4626, 4761, 4902, 5124, 5261, 5398, 5537, 5673, 5837, 6039, 6187, 6354, 6496, 6641, 6931, 7077, 7243, 7385, 7529, 7670, 7816, 7958, 8140, 8329, 8454]
#
# Datapoint #10 in redBans:
# ==>	['RekSai', 'Lissandra', 'Kassadin']
#
# Datapoint #10 in Address:
# ==>	http://matchhistory.na.leagueoflegends.com/en/#match-details/TRLH1/1001000016?gameHash=e8fbe00273df6ede
#
# Datapoint #10 in bKills_pre15:
# ==>	0
#
# Datapoint #10 in rKills_pre15:
# ==>	0
#
# Datapoint #10 in bTowers_pre15:
# ==>	1
#
# Datapoint #10 in rTowers_pre15:
# ==>	0
#
# Datapoint #10 in bInhibs_pre15:
# ==>	0
#
# Datapoint #10 in rInhibs_pre15:
# ==>	0
#
# Datapoint #10 in bDragons_pre15:
# ==>	0
#
# Datapoint #10 in rDragons_pre15:
# ==>	1
#
# Datapoint #10 in bBarons_pre15:
# ==>	0
#
# Datapoint #10 in rBarons_pre15:
# ==>	0
#
# Datapoint #10 in bHeralds_pre15:
# ==>	0
#
# Datapoint #10 in rHeralds_pre15:
# ==>	0
#
# Datapoint #10 in TopgoldDiff:
# ==>	[    0     0     0   -15   -30   -76   -65  -127  -163  -180  -212   -85
#   -205  -196  -347  -386  -724  -990 -1140 -1134 -1234 -1461 -1367 -1431
#  -1588 -1570 -1324 -1103 -1343 -1397 -1578 -1640 -1746 -1729 -1526 -1531
#  -1514 -1691 -1821 -1752 -1667 -1747 -1801 -1870 -1955 -1452 -1510 -1480
#  -1865 -2190 -2288 -2444]
#
# Datapoint #10 in MidgoldDiff:
# ==>	[    0     0     0    65    55   115    70    23   -75   -26  -258  -233
#   -243  -298  -395  -265  -502  -460  -488  -612  -524 -1081 -1207  -784
#   -773  -907  -873 -1021 -1269 -1069 -1164 -1147 -1001 -1229 -1137 -1198
#  -1186  -867  -908  -758  -312  -293  -423  -450  -316  -176   147   -51
#      7  -219  -159  -422]
#
# Datapoint #10 in JunglegoldDiff:
# ==>	[    0     0     0   107    61   -79   -94  -107   -46  -178   -35   -23
#    -34   -52  -325  -125  -103  -261  -439  -454  -526  -769  -852  -994
#   -960 -1202 -1248 -1312 -1500 -1791 -1604 -1560 -1584 -1624 -1348 -1348
#  -1585 -1746 -1761 -1591 -1602 -1798 -1688 -1999 -2055 -2106 -2096 -2096
#  -2357 -2792 -3015 -3042]
#
# Datapoint #10 in SupportgoldDiff:
# ==>	[    0    10    15    27    18    -7   -24   -30   -34   -28   -39   -83
#    -74   -88   -42    12   -70  -269  -274  -332  -317  -567  -576  -633
#   -506  -498  -497  -517  -850  -864  -778  -850  -882  -916  -984  -959
#  -1044 -1031 -1051 -1042 -1033 -1074 -1107 -1079 -1080 -1082 -1152 -1173
#  -1187 -1532 -1668 -2031]
#
# Datapoint #10 in ADCgoldDiff:
# ==>	[    0     0     0    90    50    96   -21   119   -73   -11    10   -38
#    -55   -70  -274  -225  -312  -653  -465  -446  -473  -901  -780 -1059
#   -883  -979  -877  -983 -1303 -1077 -1413 -1467 -1587 -1312 -1497 -1719
#  -1970 -2116 -2033 -2225 -2449 -2264 -2505 -2309 -2474 -2251 -2233 -2163
#  -2695 -3230 -3398 -4273]
#
# Datapoint #10 in golddiff_min15:
# ==>	989
#
# Datapoint #10 in golddiff_final:
# ==>	12212

# %% [markdown]
# ### Save to new csv file

# %%
df.to_csv('LOL/Clean_LeagueofLegends.csv')
